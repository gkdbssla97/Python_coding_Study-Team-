# %% [markdown]
# <a href="https://colab.research.google.com/github/gkdbssla97/Python_coding_Study-Team-/blob/main/1%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C2_%EC%A0%84%EC%9C%A0%EC%A0%95_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list = []
for i in range(9):
  S = int(input())
  list.append(S)
max = 0 
for i in range(9):
  if list[i] > max:
    max = list[i]
    r= i+1
print(max)
print(r)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 10
# 1
